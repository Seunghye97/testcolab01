# %%
#DT스쿨 나이 최솟값 최댓값 구하기
alist = {
    '1팀':[20,21,33,23], 
    '2팀':[10,10,20,30,25], 
    '3팀':[20,30,25,30],
    '4팀':[20,20,20,20],
    '5팀':[30,30,20,20,10],
    '6팀':[20,20,25,30]}
age_li = []
for i,v in alist.items():
    print(f'{i}의 최저연령은{min(v)} 최고연령은 {max(v)}')
    age_li.extend(v)
    # print(age_li)
print(f'DT스쿨 최저연령은{min(age_li)} 최고연령은 {max(age_li)}')
# Out:
# 1팀의 최저연령은20 최고연령은 33
# 2팀의 최저연령은10 최고연령은 30
# 3팀의 최저연령은20 최고연령은 30
# 4팀의 최저연령은20 최고연령은 20
# 5팀의 최저연령은10 최고연령은 30
# 6팀의 최저연령은20 최고연령은 30
# DT스쿨 최저연령은10 최고연령은 33

# %%
#문자열 나누기
text = '문자열 나누기'
li = text.split(sep=' ')  #공백값을 통해 자르고, 리스트로 만들어 준다. 
print(li)

#문자열 합치기
text2 = ' '.join(li)
print(text2)
# Out:
# '문자열 나누기'

# %%
#딕셔너리 값 가져오기
alist = {
    '키1':['값1, 값2'], 
    '키2':['값3, 값4'], 
    '키3':['값5, 값6'],
    '키4':{'키':100} }

print(list(alist['키1']))
print(alist['키4']['키'])
# Out:
# ['값1, 값2']
# 100

# %%
#우리팀 사전 만들기
team_dic = {'승혜':['러닝', 70,25,20],
            '유진':['드라마보기',60,25,25],
            '지현':['노래듣기',65,23,21],
            '창익':['당구',60,27,17], 
            '혜원':['인터넷쇼핑하기',70,28,28],
            '영은':['책읽기랑운동하기',95,25,20],'지선':['카페가기',90,23,23]}
a = input()
b_list = team_dic[a]
print(f'우리{a}님은 {b_list[0]}을 좋아해요')
print(f'체력은 {b_list[1]}! {b_list[2]}세의 신체연령에 신기하게도 정신연령은 {b_list[3]}세!')
print(f'사랑스러운 {a}님이시네요')
# Out:
# 혜원
# 우리혜원님은 인터넷쇼핑하기을 좋아해요
# 체력은 70! 28세의 신체연령에 신기하게도 정신연령은 28세!
# 사랑스러운 혜원님이시네요

# %% [markdown]
# 다른팀 예시

# %%
# team_dic = {'닉네임':[취미, mbti, 좋아하는 여행지, 가고싶은 여행지, 좋아하는 일]}
team6_dic = {'한':['영화감상', 'ENTP', '경주', '두바이', '친구랑 술마시기'],
            '인':['넥플릭스 보기', 'ENFP', '제주도', '탄자니아', '맛있는 음식 먹기'],
            '빈':['핸드폰 보기', 'ESTP', '바다 앞 어디든', '코타키나발루', '드라이브'],
            '선':['게임', 'enfj', '부산', '가평', '수다떨기'],
            '솔':['독서','ISFP','동해','다낭','보드게임과 방탈출']
}
import random
a = random.choice(team6_dic)
b_list = team6_dic[a]
print(f'{a}님을 소개합니다. {a}님의 취미는 {b_list[0]}입니다.')
print(f'mbti는 {b_list[1]}이고, 좋아하는 여행지는 {b_list[2]}, 가고싶은 여행지는 {b_list[3]}!')
print(f'좋아하는 일은 {b_list[4]}입니다!')
print(f'사랑스러운 {a}님이시네요 :D')

# %%
team_may = {'수루키':['한슬기','댄스','곱창','발리'],
            '갓디':['신동열','자전거','돈까스','아이슬란드'],
            '너구리':['이영이', '양파,감자', '잠', '뉴욕'],
            '매운오돌뼈':['박정선','책 읽기' '쫄면','크로아티아'],
            '뚜뚜':['김은수' , '노래 듣기' , '떡볶이' , '유럽'],
            '데이지':['노현정','유튜브보기','매번다름','이스탄불'],
nick_name = input('누가 궁금한가요?')
if nick_name != team_may :
    print('우리팀원이 아니에요')
b_list = team_may[nick_name]
print(f'오월의 오팀 {nick_name}님을 소개합니다.')
print(f'{nick_name}님의 이름은 {b_list[0]}.')
print(f'취미는 {b_list[1]}.')
print(f'{nick_name}님이 좋아하는 음식은 {b_list[2]} 이고,')
print(f'여행가고 싶은 곳은 {b_list[3]} 입니다!.')
print(f'우리 오월의 오팀 사랑스런 {nick_name}님을 환영해주세용♡')

# %% [markdown]
# # 얼굴인식

# %% [markdown]
# 네이버 오픈 API - https://developers.naver.com/docs/common/openapiguide/
#
# 이미지캡쳐 예시 코드 - https://developers.naver.com/docs/utils/captcha/examples/#python

# %%
import os
import sys
import requests


# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
#url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다.
files = {'image': open('/content/drive/MyDrive/오이도 사진 캡처.PNG', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))
# Out:
# {"info":{"size":{"width":521,"height":697},"faceCount":1},"faces":[{"roi":{"x":170,"y":226,"width":199,"height":199},"landmark":{"leftEye":{"x":212,"y":281},"rightEye":{"x":299,"y":258},"nose":{"x":276,"y":320},"leftMouth":{"x":241,"y":370},"rightMouth":{"x":325,"y":350}},"gender":{"value":"female","confidence":0.999985},"age":{"value":"19~23","confidence":1.0},"emotion":{"value":"smile","confidence":0.996358},"pose":{"value":"frontal_face","confidence":0.967109}}]}

# %%
# json 형식을 사용하기 위하여 import 합니다.
import json

# loads 함수를 사용하여 json으로 변환합니다.
result = json.loads(response.text)
result

# %% [markdown]
# ###팀과제
#
#
# *   네이버 오픈 API를 사용하여 검색을 요청하고 결과화면 출력
# *   본인의 얼굴 인식 나이를 확인하고 출력
# *   팀원 모두의 얼굴인식 나이를 측정하고 평균값을 측정
# *   팀과제 해결 방법 요약 자료와 함께 colab파일 제출
# *   연예인과 비교도 해보기

# %%
#드라이브 마운트 하는 법
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
import requests


# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다.
files = {'image': open('/content/drive/MyDrive/오이도 사진 캡처.PNG', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))



# json 형식을 사용하기 위하여 import 합니다.
import json

# loads 함수를 사용하여 json으로 변환합니다.
result = json.loads(response.text)
result
# Out:
# {"info":{"size":{"width":521,"height":697},"faceCount":1},"faces":[{"celebrity":{"value":"이지민","confidence":0.413435}}]}
# {'faces': [{'celebrity': {'confidence': 0.413435, 'value': '이지민'}}],
#  'info': {'faceCount': 1, 'size': {'height': 697, 'width': 521}}}

# %%
team3_age = [17, 24, 22, 22, 20, 20]
ave= int(sum(team3_age)/ len(team3_age))

print(f'3팀의 평균 나이는 {ave}살 입니다!')
# Out:
# 3팀의 평균 나이는 20살 입니다!

# %% [markdown]
# ## 다른 팀 예시

# %%
# 팀원 나이, 정확도 데이터
data = [[18, 0.849952], [19, 1.0], [20, 0.97328], [20, 0.415346], [25, 0.947715]]
# 팀원 나이, 정확도 평균 코드
sum_age = 0
sum_con = 0
for i in range(len(data)):
    sum_age += data[i][0]
    sum_con += data[i][1]
print(f'''저희 6팀의 평균나이는 {sum_age/len(data)}입니다.
나이측정 정확도 평균은 {sum_con/len(data)}입니다. :)''')
print(' ')
# 팀원 닮은꼴 연예인 데이터
team_cele = {
    '선':'이지은',
    '빈':'김태연',
    '인':'김고은',
    '한':'조여정',
    '솔':'전효성'
}
# 팀원 닮은꼴 연예인 출력 코드
for i in team_cele:
    print(f'{i} 님의 닮은꼴 연예인은 {team_cele[i]}입니다!')

# %%
team_results = [{'age': {'confidence': 0.534938, 'value': '16~20'}},
                {'age': {'confidence': 0.950639, 'value': '18~22'}},
                {'age': {'confidence': 0.319881, 'value': '21~25'}},
                {'age': {'confidence': 0.0696897, 'value': '25~29'}},
                {'age': {'confidence': 0.449355, 'value': '28~32'}}]
# 각 age 다 dict로 만들기
​
ages = 0 #dict에서 추출해올 나이값
avg = [] #각자 나이의 평균
for i in team_results:
    #i = {'age': {'confidence': 0.534938, 'value': '16~20'}}
    ages = i['age']['value'] # 각 팀원의 추정 나이 가져오기
    avg.append((int(ages.split('~')[0])+int(ages.split('~')[1]))/2)
    team_avg = sum(avg) /len(avg)
print(f'평균나이 : {team_avg}')

# %%
# 네이버 API를 이용한 팀 평균나이 / 닮은꼴 연예인 찾기 
alist = [23.2,26.25,21.6,22.7,19.6]
blist = [0.85,0.64,0.83,0.84,0.54,0.69,0.91]    
print(f'5월의 오조의 평균 연령은 {round(sum(alist)/len(alist),1)}입니다')
print(f'5월의 오조의 평균 정확도는 {round(sum(blist)/len(blist),1)} 입니다') 
print('='*50)
team_may = {'한슬기':['23.3','0.85','에리카'],
            '신동열':['26.25','0.64','윤시윤'],
            '이영이':['21.6',' 0.83','예인'],
            '박정선':['22.6','0.54','구혜선'],
            '김은수':['19.6','0.84','박보영'],
            '노현정':['27.9','0.69', '문지인'],
            '박제희':['27.9','0.91','강승현']}
nick_name = input('누가 궁금한가요? : ')
b_list = team_may[nick_name]
print(f'오월의 오조 {nick_name}님의 평균나이는 {b_list[0]}이며, 정확도는 {b_list[1]}')
print(f'{nick_name}님의 닮은꼴 연예인은? : {b_list[2]} ')
